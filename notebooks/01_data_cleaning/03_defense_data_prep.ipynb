# %% [markdown]
# # Purpose
# This notebook details how to calculate striking defense (SD). SD is the percentage of
# strikes that the fighter's opponent attempted but did not successfully land. Striking
# Defense allows us to measure how well a fighter can avoid hits. It can also indicate
# how good a fighters striking ability is in general, as defense is considered as, if
# not more, important than offense.
#
# ### Result
# This notebook will create a dataframe that will have a row for each bout and will include:
#  - Features:
#      - average successful significant strikes for each fighter (ASSS)
#      - average significant strike accuracy (ASSA)
#      - average significant strike defense (ASSD)
#  - Target:
#      - total successful significant strikes for a sing bout (TSSS_bout)

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
from sqlalchemy import create_engine
from src import local
from src import functions

# %%
# Credentials
USER = local.user 
PASS = local.password
HOST = local.host
PORT = local.port

#create engine
engine = create_engine(f'postgresql://{USER}:{PASS}@{HOST}:{PORT}/match_finder')

# %% [markdown]
# # Get data from postgres database
# ### Join tables
#
# - get the date from the events table
# - use the bouts table to join the dates to the general table
# - use the general table to join the bouts with the fighters

# %% [markdown]
# #### Accuracy case statement

# %%
accuracy_column = """
CASE 
    WHEN (sig_str_a > 0) THEN (CAST(sig_str_s AS FLOAT)/CAST(sig_str_a AS FLOAT))
    ELSE 0
END AS accuracy
"""

# %%
query = """
SELECT bout_link, fighter_link, sig_str_a, sig_str_s, "Date", round,
"""+accuracy_column+"""
FROM strikes_cleaned
JOIN bouts ON bouts.link = strikes_cleaned.bout_link
JOIN events ON events.link = bouts.event_link
"""

data = pd.read_sql(query, engine)

# %%
data = functions.format_data(data, event=False)

# %%
data
# Out:
#                                                bout_link  \
# 0      http://www.ufcstats.com/fight-details/11f715fa...
# 6      http://www.ufcstats.com/fight-details/11f715fa...
# 12     http://www.ufcstats.com/fight-details/11f715fa...
# 18     http://www.ufcstats.com/fight-details/11f715fa...
# 24     http://www.ufcstats.com/fight-details/11f715fa...
# ...                                                  ...
# 26447  http://www.ufcstats.com/fight-details/cecdc0da...
# 26448  http://www.ufcstats.com/fight-details/2d2bbc86...
# 26449  http://www.ufcstats.com/fight-details/2d2bbc86...
# 26450  http://www.ufcstats.com/fight-details/567a09fd...
# 26451  http://www.ufcstats.com/fight-details/567a09fd...
#
#                                             fighter_link  sig_str_a  \
# 0      http://www.ufcstats.com/fighter-details/e1147d...         30
# 6      http://www.ufcstats.com/fighter-details/e1147d...         30
# 12     http://www.ufcstats.com/fighter-details/e1147d...         32
# 18     http://www.ufcstats.com/fighter-details/e1147d...         34
# 24     http://www.ufcstats.com/fighter-details/e1147d...         31
# ...                                                  ...        ...
# 26447  http://www.ufcstats.com/fighter-details/a5c53b...          0
# 26448  http://www.ufcstats.com/fighter-details/598a58...         27
# 26449  http://www.ufcstats.com/fighter-details/d3711d...         28
# 26450  http://www.ufcstats.com/fighter-details/279093...          5
# 26451  http://www.ufcstats.com/fighter-details/96eff1...          1
#
#        sig_str_s               Date round  accuracy       date  \
# 0             11      July 25, 2020     1  0.366667 2020-07-25
# 6             15      July 25, 2020     2  0.500000 2020-07-25
# 12            13      July 25, 2020     3  0.406250 2020-07-25
# 18            13      July 25, 2020     4  0.382353 2020-07-25
# 24            17      July 25, 2020     5  0.548387 2020-07-25
# ...          ...                ...   ...       ...        ...
# 26447          0  November 12, 1993     1  0.000000 1993-11-12
# 26448         15  November 12, 1993     1  0.555556 1993-11-12
# 26449         12  November 12, 1993     1  0.428571 1993-11-12
# 26450          3  November 12, 1993     1  0.600000 1993-11-12
# 26451          0  November 12, 1993     1  0.000000 1993-11-12
#
#              fighter_id           bout_id
# 0      e1147d3d2dabe1ce  11f715fa5e825e51
# 6      e1147d3d2dabe1ce  11f715fa5e825e51
# 12     e1147d3d2dabe1ce  11f715fa5e825e51
# 18     e1147d3d2dabe1ce  11f715fa5e825e51
# 24     e1147d3d2dabe1ce  11f715fa5e825e51
# ...                 ...               ...
# 26447  a5c53b3ddb31cc7d  cecdc0da584274b9
# 26448  598a58db87b890ee  2d2bbc86e941e05c
# 26449  d3711d3784b76255  2d2bbc86e941e05c
# 26450  279093302a6f44b3  567a09fd200cfa05
# 26451  96eff1a628adcc7f  567a09fd200cfa05
#
# [26214 rows x 10 columns]

# %% [markdown]
# In order to get the striking defense, we need each column to include the fighters opponent.

# %%
data_0 = functions.merge_fighter_instances(data, rounds=True)
data_1 = functions.merge_fighter_instances(data, rounds=True, flip=True)

data = pd.concat((data_0, data_1))

# %%
data.columns
# Out:
# Index(['bout_link_0', 'fighter_link_0', 'sig_str_attempted_0',
#        'sig_str_successful_0', 'Date_0', 'round_0', 'accuracy_0',
#        'fighter_id_0', 'bout_id_0', 'round_id', 'inst_id_0', 'bout_link_1',
#        'fighter_link_1', 'sig_str_attempted_1', 'sig_str_successful_1',
#        'Date_1', 'round_1', 'accuracy_1', 'fighter_id_1', 'bout_id_1',
#        'inst_id_1'],
#       dtype='object')

# %%
data = data.loc[:, ['bout_link_0', 'fighter_link_0', 'sig_str_attempted_0',
                'sig_str_successful_0', 'Date_0', 'round_0', 'accuracy_0',
                'fighter_id_0', 'bout_id_0', 'round_id', 'inst_id_0', 
                'sig_str_attempted_1', 'sig_str_successful_1', 'accuracy_1']]

# %%
data
# Out:
#                                              bout_link_0  \
# 0      http://www.ufcstats.com/fight-details/11f715fa...
# 1      http://www.ufcstats.com/fight-details/11f715fa...
# 2      http://www.ufcstats.com/fight-details/11f715fa...
# 3      http://www.ufcstats.com/fight-details/11f715fa...
# 4      http://www.ufcstats.com/fight-details/11f715fa...
# ...                                                  ...
# 13102  http://www.ufcstats.com/fight-details/ac7ca2ec...
# 13103  http://www.ufcstats.com/fight-details/46acd54c...
# 13104  http://www.ufcstats.com/fight-details/cecdc0da...
# 13105  http://www.ufcstats.com/fight-details/2d2bbc86...
# 13106  http://www.ufcstats.com/fight-details/567a09fd...
#
#                                           fighter_link_0  sig_str_attempted_0  \
# 0      http://www.ufcstats.com/fighter-details/e1147d...                   30
# 1      http://www.ufcstats.com/fighter-details/e1147d...                   30
# 2      http://www.ufcstats.com/fighter-details/e1147d...                   32
# 3      http://www.ufcstats.com/fighter-details/e1147d...                   34
# 4      http://www.ufcstats.com/fighter-details/e1147d...                   31
# ...                                                  ...                  ...
# 13102  http://www.ufcstats.com/fighter-details/279093...                   17
# 13103  http://www.ufcstats.com/fighter-details/46c8ec...                    8
# 13104  http://www.ufcstats.com/fighter-details/429e7d...                    3
# 13105  http://www.ufcstats.com/fighter-details/598a58...                   27
# 13106  http://www.ufcstats.com/fighter-details/279093...                    5
#
#        sig_str_successful_0     Date_0 round_0  accuracy_0      fighter_id_0  \
# 0                        11 2020-07-25       1    0.366667  e1147d3d2dabe1ce
# 1                        15 2020-07-25       2    0.500000  e1147d3d2dabe1ce
# 2                        13 2020-07-25       3    0.406250  e1147d3d2dabe1ce
# 3                        13 2020-07-25       4    0.382353  e1147d3d2dabe1ce
# 4                        17 2020-07-25       5    0.548387  e1147d3d2dabe1ce
# ...                     ...        ...     ...         ...               ...
# 13102                    11 1993-11-12       1    0.647059  279093302a6f44b3
# 13103                     4 1993-11-12       1    0.500000  46c8ec317aff28ac
# 13104                     0 1993-11-12       1    0.000000  429e7d3725852ce9
# 13105                    15 1993-11-12       1    0.555556  598a58db87b890ee
# 13106                     3 1993-11-12       1    0.600000  279093302a6f44b3
#
#               bout_id_0           round_id                         inst_id_0  \
# 0      11f715fa5e825e51  11f715fa5e825e511  11f715fa5e825e51e1147d3d2dabe1ce
# 1      11f715fa5e825e51  11f715fa5e825e512  11f715fa5e825e51e1147d3d2dabe1ce
# 2      11f715fa5e825e51  11f715fa5e825e513  11f715fa5e825e51e1147d3d2dabe1ce
# 3      11f715fa5e825e51  11f715fa5e825e514  11f715fa5e825e51e1147d3d2dabe1ce
# 4      11f715fa5e825e51  11f715fa5e825e515  11f715fa5e825e51e1147d3d2dabe1ce
# ...                 ...                ...                               ...
# 13102  ac7ca2ec38b96c1a  ac7ca2ec38b96c1a1  ac7ca2ec38b96c1a279093302a6f44b3
# 13103  46acd54cc0c905fb  46acd54cc0c905fb1  46acd54cc0c905fb46c8ec317aff28ac
# 13104  cecdc0da584274b9  cecdc0da584274b91  cecdc0da584274b9429e7d3725852ce9
# 13105  2d2bbc86e941e05c  2d2bbc86e941e05c1  2d2bbc86e941e05c598a58db87b890ee
# 13106  567a09fd200cfa05  567a09fd200cfa051  567a09fd200cfa05279093302a6f44b3
#
#        sig_str_attempted_1  sig_str_successful_1  accuracy_1
# 0                       24                    12    0.500000
# 1                       12                     3    0.250000
# 2                       21                     6    0.285714
# 3                       19                     8    0.421053
# 4                       23                    12    0.521739
# ...                    ...                   ...         ...
# 13102                    3                     0    0.000000
# 13103                    1                     1    1.000000
# 13104                    0                     0    0.000000
# 13105                   28                    12    0.428571
# 13106                    1                     0    0.000000
#
# [26214 rows x 14 columns]

# %% [markdown]
# ### Calculating significant strike defense can be done by simply subtracting their opponents accuracy from 1

# %%
data['ssd_0'] = 1 - data['accuracy_1']

# %%
data
# Out:
#                                              bout_link_0  \
# 0      http://www.ufcstats.com/fight-details/11f715fa...
# 1      http://www.ufcstats.com/fight-details/11f715fa...
# 2      http://www.ufcstats.com/fight-details/11f715fa...
# 3      http://www.ufcstats.com/fight-details/11f715fa...
# 4      http://www.ufcstats.com/fight-details/11f715fa...
# ...                                                  ...
# 13102  http://www.ufcstats.com/fight-details/ac7ca2ec...
# 13103  http://www.ufcstats.com/fight-details/46acd54c...
# 13104  http://www.ufcstats.com/fight-details/cecdc0da...
# 13105  http://www.ufcstats.com/fight-details/2d2bbc86...
# 13106  http://www.ufcstats.com/fight-details/567a09fd...
#
#                                           fighter_link_0  sig_str_attempted_0  \
# 0      http://www.ufcstats.com/fighter-details/e1147d...                   30
# 1      http://www.ufcstats.com/fighter-details/e1147d...                   30
# 2      http://www.ufcstats.com/fighter-details/e1147d...                   32
# 3      http://www.ufcstats.com/fighter-details/e1147d...                   34
# 4      http://www.ufcstats.com/fighter-details/e1147d...                   31
# ...                                                  ...                  ...
# 13102  http://www.ufcstats.com/fighter-details/279093...                   17
# 13103  http://www.ufcstats.com/fighter-details/46c8ec...                    8
# 13104  http://www.ufcstats.com/fighter-details/429e7d...                    3
# 13105  http://www.ufcstats.com/fighter-details/598a58...                   27
# 13106  http://www.ufcstats.com/fighter-details/279093...                    5
#
#        sig_str_successful_0     Date_0 round_0  accuracy_0      fighter_id_0  \
# 0                        11 2020-07-25       1    0.366667  e1147d3d2dabe1ce
# 1                        15 2020-07-25       2    0.500000  e1147d3d2dabe1ce
# 2                        13 2020-07-25       3    0.406250  e1147d3d2dabe1ce
# 3                        13 2020-07-25       4    0.382353  e1147d3d2dabe1ce
# 4                        17 2020-07-25       5    0.548387  e1147d3d2dabe1ce
# ...                     ...        ...     ...         ...               ...
# 13102                    11 1993-11-12       1    0.647059  279093302a6f44b3
# 13103                     4 1993-11-12       1    0.500000  46c8ec317aff28ac
# 13104                     0 1993-11-12       1    0.000000  429e7d3725852ce9
# 13105                    15 1993-11-12       1    0.555556  598a58db87b890ee
# 13106                     3 1993-11-12       1    0.600000  279093302a6f44b3
#
#               bout_id_0           round_id                         inst_id_0  \
# 0      11f715fa5e825e51  11f715fa5e825e511  11f715fa5e825e51e1147d3d2dabe1ce
# 1      11f715fa5e825e51  11f715fa5e825e512  11f715fa5e825e51e1147d3d2dabe1ce
# 2      11f715fa5e825e51  11f715fa5e825e513  11f715fa5e825e51e1147d3d2dabe1ce
# 3      11f715fa5e825e51  11f715fa5e825e514  11f715fa5e825e51e1147d3d2dabe1ce
# 4      11f715fa5e825e51  11f715fa5e825e515  11f715fa5e825e51e1147d3d2dabe1ce
# ...                 ...                ...                               ...
# 13102  ac7ca2ec38b96c1a  ac7ca2ec38b96c1a1  ac7ca2ec38b96c1a279093302a6f44b3
# 13103  46acd54cc0c905fb  46acd54cc0c905fb1  46acd54cc0c905fb46c8ec317aff28ac
# 13104  cecdc0da584274b9  cecdc0da584274b91  cecdc0da584274b9429e7d3725852ce9
# 13105  2d2bbc86e941e05c  2d2bbc86e941e05c1  2d2bbc86e941e05c598a58db87b890ee
# 13106  567a09fd200cfa05  567a09fd200cfa051  567a09fd200cfa05279093302a6f44b3
#
#        sig_str_attempted_1  sig_str_successful_1  accuracy_1     ssd_0
# 0                       24                    12    0.500000  0.500000
# 1                       12                     3    0.250000  0.750000
# 2                       21                     6    0.285714  0.714286
# 3                       19                     8    0.421053  0.578947
# 4                       23                    12    0.521739  0.478261
# ...                    ...                   ...         ...       ...
# 13102                    3                     0    0.000000  1.000000
# 13103                    1                     1    1.000000  0.000000
# 13104                    0                     0    0.000000  1.000000
# 13105                   28                    12    0.428571  0.571429
# 13106                    1                     0    0.000000  1.000000
#
# [26214 rows x 15 columns]

# %% [markdown]
# Clean the columns for continuity

# %%
data.columns = ['bout_link', 'fighter_link', 'sig_str_attempted',
       'sig_str_successful', 'Date', 'round', 'accuracy',
       'fighter_id', 'bout_id', 'round_id', 'inst_id',
       'sig_str_attempted_1', 'sig_str_successful_1', 'accuracy_1', 'ssd']

# %% [markdown]
# ## Create fighter-bout instance dataframe
#
# A fighter-bout instance represents one fighter in one bout.
#  - The same fighter has exactly one fighter-bout instance for every single bout he has been in.
#  - Every bout has exactly two fighter-bout instances, one for each fighter in the bout.
#
# In this case a fighter-bout instance is assigned a unique identifier comprised of the bout_id combined with the fighter_link.

# %%
fighter_bout_inst = functions.create_fighter_bout_instance_table(data)

# %%
fighter_bout_inst
# Out:
#                                            bout_id        fighter_id  \
# fighter_bout_inst
# 000da3152b7b5ab16da99156486ed6c2  000da3152b7b5ab1  6da99156486ed6c2
# 000da3152b7b5ab1d1a1314976c50bef  000da3152b7b5ab1  d1a1314976c50bef
# 0019ec81fd706ade326f94d6cfb1bf25  0019ec81fd706ade  326f94d6cfb1bf25
# 0019ec81fd706ade85073dbd1be65ed9  0019ec81fd706ade  85073dbd1be65ed9
# 0027e179b743c86c3aa794cbe1e3484b  0027e179b743c86c  3aa794cbe1e3484b
# ...                                            ...               ...
# ffe629a5232a878bb361180739bed4b0  ffe629a5232a878b  b361180739bed4b0
# ffea776913451b6d22a92d7f62195791  ffea776913451b6d  22a92d7f62195791
# ffea776913451b6d75e5fec9f72910ef  ffea776913451b6d  75e5fec9f72910ef
# fffa21388cdd78b75d7bdab5e03e3216  fffa21388cdd78b7  5d7bdab5e03e3216
# fffa21388cdd78b7c80095f6092271a7  fffa21388cdd78b7  c80095f6092271a7
#
#                                        date  sss_bout
# fighter_bout_inst
# 000da3152b7b5ab16da99156486ed6c2 2006-07-08        35
# 000da3152b7b5ab1d1a1314976c50bef 2006-07-08        19
# 0019ec81fd706ade326f94d6cfb1bf25 2019-10-18        26
# 0019ec81fd706ade85073dbd1be65ed9 2019-10-18        54
# 0027e179b743c86c3aa794cbe1e3484b 2015-03-14         9
# ...                                     ...       ...
# ffe629a5232a878bb361180739bed4b0 2003-06-06         0
# ffea776913451b6d22a92d7f62195791 2015-02-28        11
# ffea776913451b6d75e5fec9f72910ef 2015-02-28         2
# fffa21388cdd78b75d7bdab5e03e3216 2013-10-19        57
# fffa21388cdd78b7c80095f6092271a7 2013-10-19        41
#
# [11362 rows x 4 columns]

# %% [markdown]
# ## Calculate metrics
#
# The metrics I will using in this notebook are:
#  - average successful significant strikes for each fighter (ASSS)
#  - average significant strike accuracy (ASSA)
#  - average significant strike defense (ASSD)

# %%
assa = fighter_bout_inst.apply(lambda row: functions.calculate_metric_average('accuracy', row['fighter_id'], row['date'], data), axis=1)
fighter_bout_inst['assa'] = assa

# %%
asss = fighter_bout_inst.apply(lambda row: functions.calculate_metric_average('sig_str_successful', row['fighter_id'], row['date'], data), axis=1)
fighter_bout_inst['asss'] = asss

# %%
assd = fighter_bout_inst.apply(lambda row: functions.calculate_metric_average('ssd', row['fighter_id'], row['date'], data), axis=1)
fighter_bout_inst['assd'] = assd

# %%
fighter_bout_inst
# Out:
#                                            bout_id        fighter_id  \
# fighter_bout_inst
# 000da3152b7b5ab16da99156486ed6c2  000da3152b7b5ab1  6da99156486ed6c2
# 000da3152b7b5ab1d1a1314976c50bef  000da3152b7b5ab1  d1a1314976c50bef
# 0019ec81fd706ade326f94d6cfb1bf25  0019ec81fd706ade  326f94d6cfb1bf25
# 0019ec81fd706ade85073dbd1be65ed9  0019ec81fd706ade  85073dbd1be65ed9
# 0027e179b743c86c3aa794cbe1e3484b  0027e179b743c86c  3aa794cbe1e3484b
# ...                                            ...               ...
# ffe629a5232a878bb361180739bed4b0  ffe629a5232a878b  b361180739bed4b0
# ffea776913451b6d22a92d7f62195791  ffea776913451b6d  22a92d7f62195791
# ffea776913451b6d75e5fec9f72910ef  ffea776913451b6d  75e5fec9f72910ef
# fffa21388cdd78b75d7bdab5e03e3216  fffa21388cdd78b7  5d7bdab5e03e3216
# fffa21388cdd78b7c80095f6092271a7  fffa21388cdd78b7  c80095f6092271a7
#
#                                        date  sss_bout      assa       asss  \
# fighter_bout_inst
# 000da3152b7b5ab16da99156486ed6c2 2006-07-08        35  0.601620   7.750000
# 000da3152b7b5ab1d1a1314976c50bef 2006-07-08        19  0.281351   9.800000
# 0019ec81fd706ade326f94d6cfb1bf25 2019-10-18        26       NaN        NaN
# 0019ec81fd706ade85073dbd1be65ed9 2019-10-18        54  0.568124  19.750000
# 0027e179b743c86c3aa794cbe1e3484b 2015-03-14         9  0.359259   6.666667
# ...                                     ...       ...       ...        ...
# ffe629a5232a878bb361180739bed4b0 2003-06-06         0  0.493956   8.055556
# ffea776913451b6d22a92d7f62195791 2015-02-28        11  0.333091  16.266667
# ffea776913451b6d75e5fec9f72910ef 2015-02-28         2  0.343625   9.278689
# fffa21388cdd78b75d7bdab5e03e3216 2013-10-19        57  0.446893   9.500000
# fffa21388cdd78b7c80095f6092271a7 2013-10-19        41  0.489039  12.533333
#
#                                       assd
# fighter_bout_inst
# 000da3152b7b5ab16da99156486ed6c2  0.563305
# 000da3152b7b5ab1d1a1314976c50bef  0.543474
# 0019ec81fd706ade326f94d6cfb1bf25       NaN
# 0019ec81fd706ade85073dbd1be65ed9  0.610863
# 0027e179b743c86c3aa794cbe1e3484b  0.561818
# ...                                    ...
# ffe629a5232a878bb361180739bed4b0  0.487001
# ffea776913451b6d22a92d7f62195791  0.717127
# ffea776913451b6d75e5fec9f72910ef  0.646161
# fffa21388cdd78b75d7bdab5e03e3216  0.572856
# fffa21388cdd78b7c80095f6092271a7  0.590146
#
# [11362 rows x 7 columns]

# %% [markdown]
# ### Remove debut fights
# There isn't any historical data for fighters with debut fights, so for now we will not use them in our analysis.

# %%
def black_list_entry(entry, black_list):
    return entry not in black_list

# %%
import pickle

# %%
debut_bouts = list(fighter_bout_inst[fighter_bout_inst.asss.isna()].bout_id.unique())
pickle.dump(debut_bouts, open('../../src/debut_bouts.pkl', 'wb')) # this will be used when I create a function for this step

# %%
mask = fighter_bout_inst['bout_id'].map(lambda x: black_list_entry(x, debut_bouts))

fighter_bout_inst = fighter_bout_inst[mask]

fighter_bout_inst

# %% [markdown]
# ## Create the final dataframe
#
# First I will get a list af all bout ids. Then I will create a dataframe with the first row and another dataframe with the second row. Then I will join those dataframes along the column axis.

# %%
fighter_bout_inst['fighter_id'] = fighter_bout_inst['fighter_link'].map(functions.get_id)
# Out:
# <ipython-input-35-43ede28b8cc5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fighter_bout_inst['fighter_id'] = fighter_bout_inst['fighter_link'].map(functions.get_id)

# %%
model_df = functions.merge_fighter_instances(fighter_bout_inst)

# %% [markdown]
# ## Creating tsss_bout
#
# tsss_bout: Total Successful Significant Strikes for the Bout. This metric measure the combined total number of significant strikes in a bout.

# %%
model_df['tsss_bout'] = model_df['sss_bout_0'] + model_df['sss_bout_1']
model_df
# Out:
#                bout_id                                     fighter_link_0  \
# 0     000da3152b7b5ab1  http://www.ufcstats.com/fighter-details/d1a131...
# 1     0027e179b743c86c  http://www.ufcstats.com/fighter-details/91ea90...
# 2     002921976d27b7da  http://www.ufcstats.com/fighter-details/ebc1f4...
# 3     002c1562708ac307  http://www.ufcstats.com/fighter-details/44470b...
# 4     002cb1bb411c5f60  http://www.ufcstats.com/fighter-details/d89789...
# ...                ...                                                ...
# 4033  ffbc12e4f821ec68  http://www.ufcstats.com/fighter-details/7a703c...
# 4034  ffd3e3d37cba32da  http://www.ufcstats.com/fighter-details/92a9aa...
# 4035  ffe629a5232a878b  http://www.ufcstats.com/fighter-details/b36118...
# 4036  ffea776913451b6d  http://www.ufcstats.com/fighter-details/75e5fe...
# 4037  fffa21388cdd78b7  http://www.ufcstats.com/fighter-details/c80095...
#
#          date_0  sss_bout_0    assa_0     asss_0    assd_0      fighter_id_0  \
# 0    2006-07-08          19  0.281351   9.800000  0.543474  d1a1314976c50bef
# 1    2015-03-14          22  0.598198  12.900000  0.546091  91ea901c458e95dd
# 2    2014-12-13           2  0.437190  11.954545  0.487594  ebc1f40e00e0c481
# 3    2014-05-24          22  0.486772   7.666667  0.775809  44470bfd9483c7ad
# 4    2006-03-04         127  0.471745  20.636364  0.647542  d897897060f10a3a
# ...         ...         ...       ...        ...       ...               ...
# 4033 2014-02-15          16  0.541667  18.000000  0.811688  7a703c565ccaa18f
# 4034 2014-10-25          47  0.315385  12.272727  0.634401  92a9aa9c93192871
# 4035 2003-06-06           0  0.493956   8.055556  0.487001  b361180739bed4b0
# 4036 2015-02-28           2  0.343625   9.278689  0.646161  75e5fec9f72910ef
# 4037 2013-10-19          41  0.489039  12.533333  0.590146  c80095f6092271a7
#
#                              inst_id_0  \
# 0     000da3152b7b5ab1d1a1314976c50bef
# 1     0027e179b743c86c91ea901c458e95dd
# 2     002921976d27b7daebc1f40e00e0c481
# 3     002c1562708ac30744470bfd9483c7ad
# 4     002cb1bb411c5f60d897897060f10a3a
# ...                                ...
# 4033  ffbc12e4f821ec687a703c565ccaa18f
# 4034  ffd3e3d37cba32da92a9aa9c93192871
# 4035  ffe629a5232a878bb361180739bed4b0
# 4036  ffea776913451b6d75e5fec9f72910ef
# 4037  fffa21388cdd78b7c80095f6092271a7
#
#                                          fighter_link_1     date_1  \
# 0     http://www.ufcstats.com/fighter-details/6da991... 2006-07-08
# 1     http://www.ufcstats.com/fighter-details/3aa794... 2015-03-14
# 2     http://www.ufcstats.com/fighter-details/b4ad3a... 2014-12-13
# 3     http://www.ufcstats.com/fighter-details/22a92d... 2014-05-24
# 4     http://www.ufcstats.com/fighter-details/22e47b... 2006-03-04
# ...                                                 ...        ...
# 4033  http://www.ufcstats.com/fighter-details/3591d0... 2014-02-15
# 4034  http://www.ufcstats.com/fighter-details/7413b8... 2014-10-25
# 4035  http://www.ufcstats.com/fighter-details/08ae5c... 2003-06-06
# 4036  http://www.ufcstats.com/fighter-details/22a92d... 2015-02-28
# 4037  http://www.ufcstats.com/fighter-details/5d7bda... 2013-10-19
#
#       sss_bout_1    assa_1     asss_1    assd_1      fighter_id_1  \
# 0             35  0.601620   7.750000  0.563305  6da99156486ed6c2
# 1              9  0.359259   6.666667  0.561818  3aa794cbe1e3484b
# 2             17  0.774253  21.444444  0.667550  b4ad3a06ee4d660c
# 3             38  0.314773  18.111111  0.673899  22a92d7f62195791
# 4             21  0.484044  11.222222  0.498367  22e47b53e4ceb27c
# ...          ...       ...        ...       ...               ...
# 4033          19  0.519991   9.875000  0.617094  3591d0d5d382a381
# 4034          26  0.424009  14.250000  0.543519  7413b80dbb0f8f9f
# 4035           1  0.514747   6.400000  0.547333  08ae5cd9aef7ddd3
# 4036          11  0.333091  16.266667  0.717127  22a92d7f62195791
# 4037          57  0.446893   9.500000  0.572856  5d7bdab5e03e3216
#
#                              inst_id_1  tsss_bout
# 0     000da3152b7b5ab16da99156486ed6c2         54
# 1     0027e179b743c86c3aa794cbe1e3484b         31
# 2     002921976d27b7dab4ad3a06ee4d660c         19
# 3     002c1562708ac30722a92d7f62195791         60
# 4     002cb1bb411c5f6022e47b53e4ceb27c        148
# ...                                ...        ...
# 4033  ffbc12e4f821ec683591d0d5d382a381         35
# 4034  ffd3e3d37cba32da7413b80dbb0f8f9f         73
# 4035  ffe629a5232a878b08ae5cd9aef7ddd3          1
# 4036  ffea776913451b6d22a92d7f62195791         13
# 4037  fffa21388cdd78b75d7bdab5e03e3216         98
#
# [4038 rows x 18 columns]

# %%
model_df = model_df.loc[:,['asss_0', 'assa_0', 'assd_0', 'asss_1', 'assa_1', 'assd_1', 'tsss_bout']]

# %%
model_df
# Out:
#          asss_0    assa_0    assd_0     asss_1    assa_1    assd_1  tsss_bout
# 0      9.800000  0.281351  0.543474   7.750000  0.601620  0.563305         54
# 1     12.900000  0.598198  0.546091   6.666667  0.359259  0.561818         31
# 2     11.954545  0.437190  0.487594  21.444444  0.774253  0.667550         19
# 3      7.666667  0.486772  0.775809  18.111111  0.314773  0.673899         60
# 4     20.636364  0.471745  0.647542  11.222222  0.484044  0.498367        148
# ...         ...       ...       ...        ...       ...       ...        ...
# 4033  18.000000  0.541667  0.811688   9.875000  0.519991  0.617094         35
# 4034  12.272727  0.315385  0.634401  14.250000  0.424009  0.543519         73
# 4035   8.055556  0.493956  0.487001   6.400000  0.514747  0.547333          1
# 4036   9.278689  0.343625  0.646161  16.266667  0.333091  0.717127         13
# 4037  12.533333  0.489039  0.590146   9.500000  0.446893  0.572856         98
#
# [4038 rows x 7 columns]

# %%
model_df.to_csv('../../data/model_3_data.csv')
