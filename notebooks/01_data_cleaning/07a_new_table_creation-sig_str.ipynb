# %% [markdown]
# # Purpose
# This notebook is designed to convert the existing databases into a new fighter_round_performance table.
# This notebook only creates stats for significant strikes.
#
# ### Result
#
# Fighter Round Performance:
#  - SSA - Significant Strike Attempts
#  - SSS - Significant Strike Successes
#  - SS_AC - Significant Strike Accuracy
#  - SS_DE - Significant Strike Defense
#  - SSA_DI - Significant Strike Differential
#  - SSS_DI - Significant Strike Differential
#  - SSA_P1M - Significant Strike Attempts Per 1 Minute
#  - SSS_P1M - Significant Strike Successes Per 1 Minute

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
from sqlalchemy import create_engine
from src import local
from src import functions
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Credentials
USER = local.user 
PASS = local.password
HOST = local.host
PORT = local.port

#create engine
engine = create_engine(f'postgresql://{USER}:{PASS}@{HOST}:{PORT}/match_finder')

# %% [markdown]
# # Get data from postgres database
# ### Join tables
#
# - get the date from the events table
# - use the bouts table to join the dates to the general table
# - use the general table to join the bouts with the fighters

# %% [markdown]
# #### Accuracy case statement

# %%
accuracy_column = """
CASE 
    WHEN (sig_str_attempted > 0) THEN (CAST(sig_str_successful AS FLOAT)/CAST(sig_str_attempted AS FLOAT))
    ELSE 0
END AS accuracy
"""

# %%
query = """
SELECT bout_link, fighter_link, sig_str_attempted, 
sig_str_successful, "Date", round, "Time", 
"Round" as final_round, "Timeformat",
"""+accuracy_column+"""
FROM strikes_cleaned
JOIN bouts ON bouts.link = strikes_cleaned.bout_link
JOIN events ON events.link = bouts.event_link
"""

data = pd.read_sql(query, engine)

# %%
data = functions.format_data(data, event=False)

# %%
data
# Out:
#                                                bout_link  \
# 0      http://www.ufcstats.com/fight-details/11f715fa...
# 6      http://www.ufcstats.com/fight-details/11f715fa...
# 12     http://www.ufcstats.com/fight-details/11f715fa...
# 18     http://www.ufcstats.com/fight-details/11f715fa...
# 24     http://www.ufcstats.com/fight-details/11f715fa...
# ...                                                  ...
# 26447  http://www.ufcstats.com/fight-details/cecdc0da...
# 26448  http://www.ufcstats.com/fight-details/2d2bbc86...
# 26449  http://www.ufcstats.com/fight-details/2d2bbc86...
# 26450  http://www.ufcstats.com/fight-details/567a09fd...
# 26451  http://www.ufcstats.com/fight-details/567a09fd...
#
#                                             fighter_link  sig_str_attempted  \
# 0      http://www.ufcstats.com/fighter-details/e1147d...                 30
# 6      http://www.ufcstats.com/fighter-details/e1147d...                 30
# 12     http://www.ufcstats.com/fighter-details/e1147d...                 32
# 18     http://www.ufcstats.com/fighter-details/e1147d...                 34
# 24     http://www.ufcstats.com/fighter-details/e1147d...                 31
# ...                                                  ...                ...
# 26447  http://www.ufcstats.com/fighter-details/a5c53b...                  0
# 26448  http://www.ufcstats.com/fighter-details/598a58...                 27
# 26449  http://www.ufcstats.com/fighter-details/d3711d...                 28
# 26450  http://www.ufcstats.com/fighter-details/279093...                  5
# 26451  http://www.ufcstats.com/fighter-details/96eff1...                  1
#
#        sig_str_successful               Date round  Time  final_round  \
# 0                      11      July 25, 2020     1  5:00            5
# 6                      15      July 25, 2020     2  5:00            5
# 12                     13      July 25, 2020     3  5:00            5
# 18                     13      July 25, 2020     4  5:00            5
# 24                     17      July 25, 2020     5  5:00            5
# ...                   ...                ...   ...   ...          ...
# 26447                   0  November 12, 1993     1  2:18            1
# 26448                  15  November 12, 1993     1  4:20            1
# 26449                  12  November 12, 1993     1  4:20            1
# 26450                   3  November 12, 1993     1  0:26            1
# 26451                   0  November 12, 1993     1  0:26            1
#
#               Timeformat  accuracy       date        fighter_id  \
# 0      5 Rnd (5-5-5-5-5)  0.366667 2020-07-25  e1147d3d2dabe1ce
# 6      5 Rnd (5-5-5-5-5)  0.500000 2020-07-25  e1147d3d2dabe1ce
# 12     5 Rnd (5-5-5-5-5)  0.406250 2020-07-25  e1147d3d2dabe1ce
# 18     5 Rnd (5-5-5-5-5)  0.382353 2020-07-25  e1147d3d2dabe1ce
# 24     5 Rnd (5-5-5-5-5)  0.548387 2020-07-25  e1147d3d2dabe1ce
# ...                  ...       ...        ...               ...
# 26447      No Time Limit  0.000000 1993-11-12  a5c53b3ddb31cc7d
# 26448      No Time Limit  0.555556 1993-11-12  598a58db87b890ee
# 26449      No Time Limit  0.428571 1993-11-12  d3711d3784b76255
# 26450      No Time Limit  0.600000 1993-11-12  279093302a6f44b3
# 26451      No Time Limit  0.000000 1993-11-12  96eff1a628adcc7f
#
#                 bout_id
# 0      11f715fa5e825e51
# 6      11f715fa5e825e51
# 12     11f715fa5e825e51
# 18     11f715fa5e825e51
# 24     11f715fa5e825e51
# ...                 ...
# 26447  cecdc0da584274b9
# 26448  2d2bbc86e941e05c
# 26449  2d2bbc86e941e05c
# 26450  567a09fd200cfa05
# 26451  567a09fd200cfa05
#
# [26214 rows x 13 columns]

# %%
data_original = data

# %% [markdown]
# In order to get the striking defense, we need each column to include the fighters opponent.

# %%
data_0 = functions.merge_fighter_instances(data, rounds=True)
data_1 = functions.merge_fighter_instances(data, rounds=True, flip=True)

data = pd.concat((data_0, data_1))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26214 entries, 0 to 13106
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bout_link_0           26214 non-null  object
#  1   fighter_link_0        26214 non-null  object
#  2   sig_str_attempted_0   26214 non-null  int64
#  3   sig_str_successful_0  26214 non-null  int64
#  4   Date_0                26214 non-null  object
#  5   round_0               26214 non-null  object
#  6   Time_0                26214 non-null  object
#  7   final_round_0         26214 non-null  int64
#  8   Timeformat_0          26214 non-null  object
#  9   accuracy_0            26214 non-null  float64
#  10  date_0                26214 non-null  datetime64[ns]
#  11  fighter_id_0          26214 non-null  object
#  12  bout_id_0             26214 non-null  object
#  13  round_id              26214 non-null  object
#  14  inst_id_0             26214 non-null  object
#  15  bout_link_1           26214 non-null  object
#  16  fighter_link_1        26214 non-null  object
#  17  sig_str_attempted_1   26214 non-null  int64
#  18  sig_str_successful_1  26214 non-null  int64
#  19  Date_1                26214 non-null  object
#  20  round_1               26214 non-null  object
#  21  Time_1                26214 non-null  object
#  22  final_round_1         26214 non-null  int64
#  23  Timeformat_1          26214 non-null  object
#  24  accuracy_1            26214 non-null  float64
#  25  date_1                26214 non-null  datetime64[ns]
#  26  fighter_id_1          26214 non-null  object
#  27  bout_id_1             26214 non-null  object
#  28  inst_id_1             26214 non-null  object
# dtypes: datetime64[ns](2), float64(2), int64(6), object(19)
# memory usage: 6.0+ MB

# %%
data = data.loc[:, ['bout_link_0', 'fighter_link_0', 'sig_str_attempted_0',
                    'sig_str_successful_0', 'date_0', 'round_0', 'accuracy_0',
                    'fighter_id_0', 'bout_id_0', 'round_id', 'inst_id_0', 
                    'sig_str_attempted_1', 'sig_str_successful_1', 'accuracy_1',
                    'Time_0', 'Timeformat_0', 'fighter_id_1']]

# %%
data
# Out:
#                                              bout_link_0  \
# 0      http://www.ufcstats.com/fight-details/11f715fa...
# 1      http://www.ufcstats.com/fight-details/11f715fa...
# 2      http://www.ufcstats.com/fight-details/11f715fa...
# 3      http://www.ufcstats.com/fight-details/11f715fa...
# 4      http://www.ufcstats.com/fight-details/11f715fa...
# ...                                                  ...
# 13102  http://www.ufcstats.com/fight-details/ac7ca2ec...
# 13103  http://www.ufcstats.com/fight-details/46acd54c...
# 13104  http://www.ufcstats.com/fight-details/cecdc0da...
# 13105  http://www.ufcstats.com/fight-details/2d2bbc86...
# 13106  http://www.ufcstats.com/fight-details/567a09fd...
#
#                                           fighter_link_0  sig_str_attempted_0  \
# 0      http://www.ufcstats.com/fighter-details/e1147d...                   30
# 1      http://www.ufcstats.com/fighter-details/e1147d...                   30
# 2      http://www.ufcstats.com/fighter-details/e1147d...                   32
# 3      http://www.ufcstats.com/fighter-details/e1147d...                   34
# 4      http://www.ufcstats.com/fighter-details/e1147d...                   31
# ...                                                  ...                  ...
# 13102  http://www.ufcstats.com/fighter-details/279093...                   17
# 13103  http://www.ufcstats.com/fighter-details/46c8ec...                    8
# 13104  http://www.ufcstats.com/fighter-details/429e7d...                    3
# 13105  http://www.ufcstats.com/fighter-details/598a58...                   27
# 13106  http://www.ufcstats.com/fighter-details/279093...                    5
#
#        sig_str_successful_0     date_0 round_0  accuracy_0      fighter_id_0  \
# 0                        11 2020-07-25       1    0.366667  e1147d3d2dabe1ce
# 1                        15 2020-07-25       2    0.500000  e1147d3d2dabe1ce
# 2                        13 2020-07-25       3    0.406250  e1147d3d2dabe1ce
# 3                        13 2020-07-25       4    0.382353  e1147d3d2dabe1ce
# 4                        17 2020-07-25       5    0.548387  e1147d3d2dabe1ce
# ...                     ...        ...     ...         ...               ...
# 13102                    11 1993-11-12       1    0.647059  279093302a6f44b3
# 13103                     4 1993-11-12       1    0.500000  46c8ec317aff28ac
# 13104                     0 1993-11-12       1    0.000000  429e7d3725852ce9
# 13105                    15 1993-11-12       1    0.555556  598a58db87b890ee
# 13106                     3 1993-11-12       1    0.600000  279093302a6f44b3
#
#               bout_id_0           round_id                         inst_id_0  \
# 0      11f715fa5e825e51  11f715fa5e825e511  11f715fa5e825e51e1147d3d2dabe1ce
# 1      11f715fa5e825e51  11f715fa5e825e512  11f715fa5e825e51e1147d3d2dabe1ce
# 2      11f715fa5e825e51  11f715fa5e825e513  11f715fa5e825e51e1147d3d2dabe1ce
# 3      11f715fa5e825e51  11f715fa5e825e514  11f715fa5e825e51e1147d3d2dabe1ce
# 4      11f715fa5e825e51  11f715fa5e825e515  11f715fa5e825e51e1147d3d2dabe1ce
# ...                 ...                ...                               ...
# 13102  ac7ca2ec38b96c1a  ac7ca2ec38b96c1a1  ac7ca2ec38b96c1a279093302a6f44b3
# 13103  46acd54cc0c905fb  46acd54cc0c905fb1  46acd54cc0c905fb46c8ec317aff28ac
# 13104  cecdc0da584274b9  cecdc0da584274b91  cecdc0da584274b9429e7d3725852ce9
# 13105  2d2bbc86e941e05c  2d2bbc86e941e05c1  2d2bbc86e941e05c598a58db87b890ee
# 13106  567a09fd200cfa05  567a09fd200cfa051  567a09fd200cfa05279093302a6f44b3
#
#        sig_str_attempted_1  sig_str_successful_1  accuracy_1 Time_0  \
# 0                       24                    12    0.500000   5:00
# 1                       12                     3    0.250000   5:00
# 2                       21                     6    0.285714   5:00
# 3                       19                     8    0.421053   5:00
# 4                       23                    12    0.521739   5:00
# ...                    ...                   ...         ...    ...
# 13102                    3                     0    0.000000   0:59
# 13103                    1                     1    1.000000   1:49
# 13104                    0                     0    0.000000   2:18
# 13105                   28                    12    0.428571   4:20
# 13106                    1                     0    0.000000   0:26
#
#             Timeformat_0      fighter_id_1
# 0      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7
# 1      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7
# 2      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7
# 3      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7
# 4      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7
# ...                  ...               ...
# 13102      No Time Limit  598a58db87b890ee
# 13103      No Time Limit  63b65af1c5cb02cb
# 13104      No Time Limit  a5c53b3ddb31cc7d
# 13105      No Time Limit  d3711d3784b76255
# 13106      No Time Limit  96eff1a628adcc7f
#
# [26214 rows x 17 columns]

# %% [markdown]
# ### Calculate significant strike defense by subtracting the opponents accuracy from 1

# %%
data['ss_de'] = 1 - data['accuracy_1']

# %% [markdown]
# Clean the columns for continuity

# %% [markdown]
# ## Fixing columns

# %% [markdown]
# Her we rename the columns. An important thing to note is that there are two sets of statistics. The second set, which is indicated by a '_1' suffix on the columns name, represents the stats for the opponent.

# %%
data.columns
# Out:
# Index(['bout_link_0', 'fighter_link_0', 'sig_str_attempted_0',
#        'sig_str_successful_0', 'date_0', 'round_0', 'accuracy_0',
#        'fighter_id_0', 'bout_id_0', 'round_id', 'inst_id_0',
#        'sig_str_attempted_1', 'sig_str_successful_1', 'accuracy_1', 'Time_0',
#        'Timeformat_0', 'fighter_id_1', 'ss_de'],
#       dtype='object')

# %%
data.columns = ['bout_link', 'fighter_link', 'ssa',
                'sss', 'date', 'round', 'ss_ac',
                'fighter_id', 'bout_id', 'round_id', 'inst_id',
                'ssa_1', 'sss_1', 'ss_ac_1', 
                'time', 'timeformat', 'fighter_id_1', 'ss_de']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26214 entries, 0 to 13106
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   bout_link     26214 non-null  object
#  1   fighter_link  26214 non-null  object
#  2   ssa           26214 non-null  int64
#  3   sss           26214 non-null  int64
#  4   date          26214 non-null  datetime64[ns]
#  5   round         26214 non-null  object
#  6   ss_ac         26214 non-null  float64
#  7   fighter_id    26214 non-null  object
#  8   bout_id       26214 non-null  object
#  9   round_id      26214 non-null  object
#  10  inst_id       26214 non-null  object
#  11  ssa_1         26214 non-null  int64
#  12  sss_1         26214 non-null  int64
#  13  ss_ac_1       26214 non-null  float64
#  14  time          26214 non-null  object
#  15  timeformat    26214 non-null  object
#  16  fighter_id_1  26214 non-null  object
#  17  ss_de         26214 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(10)
# memory usage: 3.8+ MB

# %%
data.columns
# Out:
# Index(['bout_link', 'fighter_link', 'ssa', 'sss', 'date', 'round', 'ss_ac',
#        'fighter_id', 'bout_id', 'round_id', 'inst_id', 'ssa_1', 'sss_1',
#        'ss_ac_1', 'time', 'timeformat', 'fighter_id_1', 'ss_de'],
#       dtype='object')

# %%
data.loc[:,['date', 'bout_id', 'fighter_id', 'round', 'ssa', 'sss',  'ss_ac', 'ss_de',
            'time', 'timeformat', 'fighter_id_1', 'ssa_1', 'sss_1', 'ss_ac_1']]
# Out:
#             date           bout_id        fighter_id round  ssa  sss  \
# 0     2020-07-25  11f715fa5e825e51  e1147d3d2dabe1ce     1   30   11
# 1     2020-07-25  11f715fa5e825e51  e1147d3d2dabe1ce     2   30   15
# 2     2020-07-25  11f715fa5e825e51  e1147d3d2dabe1ce     3   32   13
# 3     2020-07-25  11f715fa5e825e51  e1147d3d2dabe1ce     4   34   13
# 4     2020-07-25  11f715fa5e825e51  e1147d3d2dabe1ce     5   31   17
# ...          ...               ...               ...   ...  ...  ...
# 13102 1993-11-12  ac7ca2ec38b96c1a  279093302a6f44b3     1   17   11
# 13103 1993-11-12  46acd54cc0c905fb  46c8ec317aff28ac     1    8    4
# 13104 1993-11-12  cecdc0da584274b9  429e7d3725852ce9     1    3    0
# 13105 1993-11-12  2d2bbc86e941e05c  598a58db87b890ee     1   27   15
# 13106 1993-11-12  567a09fd200cfa05  279093302a6f44b3     1    5    3
#
#           ss_ac     ss_de  time         timeformat      fighter_id_1  ssa_1  \
# 0      0.366667  0.500000  5:00  5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7     24
# 1      0.500000  0.750000  5:00  5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7     12
# 2      0.406250  0.714286  5:00  5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7     21
# 3      0.382353  0.578947  5:00  5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7     19
# 4      0.548387  0.478261  5:00  5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7     23
# ...         ...       ...   ...                ...               ...    ...
# 13102  0.647059  1.000000  0:59      No Time Limit  598a58db87b890ee      3
# 13103  0.500000  0.000000  1:49      No Time Limit  63b65af1c5cb02cb      1
# 13104  0.000000  1.000000  2:18      No Time Limit  a5c53b3ddb31cc7d      0
# 13105  0.555556  0.571429  4:20      No Time Limit  d3711d3784b76255     28
# 13106  0.600000  1.000000  0:26      No Time Limit  96eff1a628adcc7f      1
#
#        sss_1   ss_ac_1
# 0         12  0.500000
# 1          3  0.250000
# 2          6  0.285714
# 3          8  0.421053
# 4         12  0.521739
# ...      ...       ...
# 13102      0  0.000000
# 13103      1  1.000000
# 13104      0  0.000000
# 13105     12  0.428571
# 13106      0  0.000000
#
# [26214 rows x 14 columns]

# %% [markdown]
# ### Calculating significant strike differential

# %%
data['sss_di'] = data['sss'] - data['sss_1']
data['ssa_di'] = data['ssa'] - data['ssa_1']

# %%
data.reset_index(inplace = True)

# %%
data[data['bout_id'] == data['bout_id'][0]]
# Out:
#        index                                          bout_link  \
# 0          0  http://www.ufcstats.com/fight-details/11f715fa...
# 1          1  http://www.ufcstats.com/fight-details/11f715fa...
# 2          2  http://www.ufcstats.com/fight-details/11f715fa...
# 3          3  http://www.ufcstats.com/fight-details/11f715fa...
# 4          4  http://www.ufcstats.com/fight-details/11f715fa...
# 13107      0  http://www.ufcstats.com/fight-details/11f715fa...
# 13108      1  http://www.ufcstats.com/fight-details/11f715fa...
# 13109      2  http://www.ufcstats.com/fight-details/11f715fa...
# 13110      3  http://www.ufcstats.com/fight-details/11f715fa...
# 13111      4  http://www.ufcstats.com/fight-details/11f715fa...
#
#                                             fighter_link  ssa  sss       date  \
# 0      http://www.ufcstats.com/fighter-details/e1147d...   30   11 2020-07-25
# 1      http://www.ufcstats.com/fighter-details/e1147d...   30   15 2020-07-25
# 2      http://www.ufcstats.com/fighter-details/e1147d...   32   13 2020-07-25
# 3      http://www.ufcstats.com/fighter-details/e1147d...   34   13 2020-07-25
# 4      http://www.ufcstats.com/fighter-details/e1147d...   31   17 2020-07-25
# 13107  http://www.ufcstats.com/fighter-details/9ce6d5...   24   12 2020-07-25
# 13108  http://www.ufcstats.com/fighter-details/9ce6d5...   12    3 2020-07-25
# 13109  http://www.ufcstats.com/fighter-details/9ce6d5...   21    6 2020-07-25
# 13110  http://www.ufcstats.com/fighter-details/9ce6d5...   19    8 2020-07-25
# 13111  http://www.ufcstats.com/fighter-details/9ce6d5...   23   12 2020-07-25
#
#       round     ss_ac        fighter_id           bout_id  ...  \
# 0         1  0.366667  e1147d3d2dabe1ce  11f715fa5e825e51  ...
# 1         2  0.500000  e1147d3d2dabe1ce  11f715fa5e825e51  ...
# 2         3  0.406250  e1147d3d2dabe1ce  11f715fa5e825e51  ...
# 3         4  0.382353  e1147d3d2dabe1ce  11f715fa5e825e51  ...
# 4         5  0.548387  e1147d3d2dabe1ce  11f715fa5e825e51  ...
# 13107     1  0.500000  9ce6d5a03af801b7  11f715fa5e825e51  ...
# 13108     2  0.250000  9ce6d5a03af801b7  11f715fa5e825e51  ...
# 13109     3  0.285714  9ce6d5a03af801b7  11f715fa5e825e51  ...
# 13110     4  0.421053  9ce6d5a03af801b7  11f715fa5e825e51  ...
# 13111     5  0.521739  9ce6d5a03af801b7  11f715fa5e825e51  ...
#
#                                 inst_id ssa_1  sss_1   ss_ac_1  time  \
# 0      11f715fa5e825e51e1147d3d2dabe1ce    24     12  0.500000  5:00
# 1      11f715fa5e825e51e1147d3d2dabe1ce    12      3  0.250000  5:00
# 2      11f715fa5e825e51e1147d3d2dabe1ce    21      6  0.285714  5:00
# 3      11f715fa5e825e51e1147d3d2dabe1ce    19      8  0.421053  5:00
# 4      11f715fa5e825e51e1147d3d2dabe1ce    23     12  0.521739  5:00
# 13107  11f715fa5e825e519ce6d5a03af801b7    30     11  0.366667  5:00
# 13108  11f715fa5e825e519ce6d5a03af801b7    30     15  0.500000  5:00
# 13109  11f715fa5e825e519ce6d5a03af801b7    32     13  0.406250  5:00
# 13110  11f715fa5e825e519ce6d5a03af801b7    34     13  0.382353  5:00
# 13111  11f715fa5e825e519ce6d5a03af801b7    31     17  0.548387  5:00
#
#               timeformat      fighter_id_1     ss_de  sss_di  ssa_di
# 0      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.500000      -1       6
# 1      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.750000      12      18
# 2      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.714286       7      11
# 3      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.578947       5      15
# 4      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.478261       5       8
# 13107  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.633333       1      -6
# 13108  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.500000     -12     -18
# 13109  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.593750      -7     -11
# 13110  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.617647      -5     -15
# 13111  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.451613      -5      -8
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Calculate SSA_P1M
# This is the Significant Strike Attempts per Minute.
#
# ### Create round length column
# First we need to have a time for each round. The current time column only measures the time on the clock at which the fight was stopped. This number can only be used for the last round. We'll group all the bout_ids and create a datafram that matches the highest round_id value to the time column.
#
# This will be based on the assumption that all rounds in the UFC are 5 minutes long, let's see if that's accurate.

# %%
data.timeformat.value_counts()
# Out:
# 3 Rnd (5-5-5)           22652
# 5 Rnd (5-5-5-5-5)        2964
# 1 Rnd + OT (12-3)         192
# 3 Rnd + OT (5-5-5-5)      106
# No Time Limit              74
# 1 Rnd + 2OT (15-3-3)       62
# 2 Rnd (5-5)                50
# 1 Rnd (20)                 42
# 1 Rnd (15)                 16
# 1 Rnd (10)                 12
# 1 Rnd (12)                  8
# 1 Rnd + OT (30-5)           6
# 1 Rnd + OT (15-3)           6
# 1 Rnd + 2OT (24-3-3)        6
# 1 Rnd + OT (27-3)           4
# 1 Rnd + OT (31-5)           4
# 1 Rnd (18)                  4
# 1 Rnd + OT (30-3)           4
# 1 Rnd (30)                  2
# Name: timeformat, dtype: int64

# %% [markdown]
# It looks like there are a lot of different round formats. They are likely from before they standardized the rules, so let's look at when these rounds took place.

# %%
data.groupby('timeformat').date.min().sort_values().index
# Out:
# Index(['No Time Limit', '1 Rnd + OT (31-5)', '1 Rnd (20)', '1 Rnd (30)',
#        '1 Rnd + OT (30-5)', '1 Rnd + OT (30-3)', '1 Rnd (15)', '1 Rnd (18)',
#        '1 Rnd + OT (27-3)', '1 Rnd (10)', '1 Rnd + 2OT (15-3-3)',
#        '1 Rnd + OT (12-3)', '1 Rnd + 2OT (24-3-3)', '1 Rnd + OT (15-3)',
#        '1 Rnd (12)', '2 Rnd (5-5)', '3 Rnd (5-5-5)', '5 Rnd (5-5-5-5-5)',
#        '3 Rnd + OT (5-5-5-5)'],
#       dtype='object', name='timeformat')

# %% [markdown]
# We'll only look at fights with five minute rounds to make the calculation easier.

# %%
non_standard_rounds = ['No Time Limit', '1 Rnd + OT (31-5)', '1 Rnd (20)', '1 Rnd (30)',
                   '1 Rnd + OT (30-5)', '1 Rnd + OT (30-3)', '1 Rnd (15)', '1 Rnd (18)',
                   '1 Rnd + OT (27-3)', '1 Rnd (10)', '1 Rnd + 2OT (15-3-3)',
                   '1 Rnd + OT (12-3)', '1 Rnd + 2OT (24-3-3)', '1 Rnd + OT (15-3)',
                   '1 Rnd (12)']

mask = data.timeformat.map(lambda x: functions.black_list_entry(x, non_standard_rounds))
new_data = data[mask]
new_data.timeformat.value_counts()
# Out:
# 3 Rnd (5-5-5)           22652
# 5 Rnd (5-5-5-5-5)        2964
# 3 Rnd + OT (5-5-5-5)      106
# 2 Rnd (5-5)                50
# Name: timeformat, dtype: int64

# %%
data = new_data

# %% [markdown]
# We still have most of our fights, so we'll use this as our timeframe from now on.

# %%
bout_groups = data.groupby('bout_id')
round_id = bout_groups.round_id.max()
round_length = bout_groups.time.max()

final_round_lengths = pd.DataFrame(dict(round_id = round_id, round_length = round_length))

# %%
final_round_lengths.set_index('round_id', inplace=True)
final_round_lengths
# Out:
#                   round_length
# round_id
# 000da3152b7b5ab13         5:00
# 0019ec81fd706ade3         5:00
# 0027e179b743c86c3         3:12
# 002921976d27b7da1         4:13
# 002c1562708ac3071         4:06
# ...                        ...
# ffd3e3d37cba32da3         5:00
# ffe4379d6bd1e82b2         1:43
# ffe629a5232a878b1         1:59
# ffea776913451b6d1         2:37
# fffa21388cdd78b73         5:00
#
# [5493 rows x 1 columns]

# %%
new_data = data.join(final_round_lengths, on='round_id', how='outer')
new_data.head(15)
# Out:
#        index                                          bout_link  \
# 0          0  http://www.ufcstats.com/fight-details/11f715fa...
# 13107      0  http://www.ufcstats.com/fight-details/11f715fa...
# 1          1  http://www.ufcstats.com/fight-details/11f715fa...
# 13108      1  http://www.ufcstats.com/fight-details/11f715fa...
# 2          2  http://www.ufcstats.com/fight-details/11f715fa...
# 13109      2  http://www.ufcstats.com/fight-details/11f715fa...
# 3          3  http://www.ufcstats.com/fight-details/11f715fa...
# 13110      3  http://www.ufcstats.com/fight-details/11f715fa...
# 4          4  http://www.ufcstats.com/fight-details/11f715fa...
# 13111      4  http://www.ufcstats.com/fight-details/11f715fa...
# 5          5  http://www.ufcstats.com/fight-details/a3820f1e...
# 13112      5  http://www.ufcstats.com/fight-details/a3820f1e...
# 6          6  http://www.ufcstats.com/fight-details/a3820f1e...
# 13113      6  http://www.ufcstats.com/fight-details/a3820f1e...
# 7          7  http://www.ufcstats.com/fight-details/a3820f1e...
#
#                                             fighter_link  ssa  sss       date  \
# 0      http://www.ufcstats.com/fighter-details/e1147d...   30   11 2020-07-25
# 13107  http://www.ufcstats.com/fighter-details/9ce6d5...   24   12 2020-07-25
# 1      http://www.ufcstats.com/fighter-details/e1147d...   30   15 2020-07-25
# 13108  http://www.ufcstats.com/fighter-details/9ce6d5...   12    3 2020-07-25
# 2      http://www.ufcstats.com/fighter-details/e1147d...   32   13 2020-07-25
# 13109  http://www.ufcstats.com/fighter-details/9ce6d5...   21    6 2020-07-25
# 3      http://www.ufcstats.com/fighter-details/e1147d...   34   13 2020-07-25
# 13110  http://www.ufcstats.com/fighter-details/9ce6d5...   19    8 2020-07-25
# 4      http://www.ufcstats.com/fighter-details/e1147d...   31   17 2020-07-25
# 13111  http://www.ufcstats.com/fighter-details/9ce6d5...   23   12 2020-07-25
# 5      http://www.ufcstats.com/fighter-details/73e09f...   30   13 2020-07-25
# 13112  http://www.ufcstats.com/fighter-details/140745...   36   16 2020-07-25
# 6      http://www.ufcstats.com/fighter-details/73e09f...   39   15 2020-07-25
# 13113  http://www.ufcstats.com/fighter-details/140745...   31   15 2020-07-25
# 7      http://www.ufcstats.com/fighter-details/73e09f...   31   18 2020-07-25
#
#       round     ss_ac        fighter_id           bout_id  ... ssa_1 sss_1  \
# 0         1  0.366667  e1147d3d2dabe1ce  11f715fa5e825e51  ...    24    12
# 13107     1  0.500000  9ce6d5a03af801b7  11f715fa5e825e51  ...    30    11
# 1         2  0.500000  e1147d3d2dabe1ce  11f715fa5e825e51  ...    12     3
# 13108     2  0.250000  9ce6d5a03af801b7  11f715fa5e825e51  ...    30    15
# 2         3  0.406250  e1147d3d2dabe1ce  11f715fa5e825e51  ...    21     6
# 13109     3  0.285714  9ce6d5a03af801b7  11f715fa5e825e51  ...    32    13
# 3         4  0.382353  e1147d3d2dabe1ce  11f715fa5e825e51  ...    19     8
# 13110     4  0.421053  9ce6d5a03af801b7  11f715fa5e825e51  ...    34    13
# 4         5  0.548387  e1147d3d2dabe1ce  11f715fa5e825e51  ...    23    12
# 13111     5  0.521739  9ce6d5a03af801b7  11f715fa5e825e51  ...    31    17
# 5         1  0.433333  73e09f837f3b5ecc  a3820f1eb82f2ba6  ...    36    16
# 13112     1  0.444444  140745cbbcb023ac  a3820f1eb82f2ba6  ...    30    13
# 6         2  0.384615  73e09f837f3b5ecc  a3820f1eb82f2ba6  ...    31    15
# 13113     2  0.483871  140745cbbcb023ac  a3820f1eb82f2ba6  ...    39    15
# 7         3  0.580645  73e09f837f3b5ecc  a3820f1eb82f2ba6  ...    36    23
#
#         ss_ac_1  time         timeformat      fighter_id_1     ss_de sss_di  \
# 0      0.500000  5:00  5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.500000     -1
# 13107  0.366667  5:00  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.633333      1
# 1      0.250000  5:00  5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.750000     12
# 13108  0.500000  5:00  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.500000    -12
# 2      0.285714  5:00  5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.714286      7
# 13109  0.406250  5:00  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.593750     -7
# 3      0.421053  5:00  5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.578947      5
# 13110  0.382353  5:00  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.617647     -5
# 4      0.521739  5:00  5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.478261      5
# 13111  0.548387  5:00  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.451613     -5
# 5      0.444444  5:00      3 Rnd (5-5-5)  140745cbbcb023ac  0.555556     -3
# 13112  0.433333  5:00      3 Rnd (5-5-5)  73e09f837f3b5ecc  0.566667      3
# 6      0.483871  5:00      3 Rnd (5-5-5)  140745cbbcb023ac  0.516129      0
# 13113  0.384615  5:00      3 Rnd (5-5-5)  73e09f837f3b5ecc  0.615385      0
# 7      0.638889  5:00      3 Rnd (5-5-5)  140745cbbcb023ac  0.361111     -5
#
#        ssa_di  round_length
# 0           6           NaN
# 13107      -6           NaN
# 1          18           NaN
# 13108     -18           NaN
# 2          11           NaN
# 13109     -11           NaN
# 3          15           NaN
# 13110     -15           NaN
# 4           8          5:00
# 13111      -8          5:00
# 5          -6           NaN
# 13112       6           NaN
# 6           8           NaN
# 13113      -8           NaN
# 7          -5          5:00
#
# [15 rows x 22 columns]

# %% [markdown]
#  Now that we have the final rounds filled in, ever null value should be '5:00'.

# %%
new_data.round_length = new_data.round_length.fillna('5:00')

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25772 entries, 0 to 25992
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         25772 non-null  int64
#  1   bout_link     25772 non-null  object
#  2   fighter_link  25772 non-null  object
#  3   ssa           25772 non-null  int64
#  4   sss           25772 non-null  int64
#  5   date          25772 non-null  datetime64[ns]
#  6   round         25772 non-null  object
#  7   ss_ac         25772 non-null  float64
#  8   fighter_id    25772 non-null  object
#  9   bout_id       25772 non-null  object
#  10  round_id      25772 non-null  object
#  11  inst_id       25772 non-null  object
#  12  ssa_1         25772 non-null  int64
#  13  sss_1         25772 non-null  int64
#  14  ss_ac_1       25772 non-null  float64
#  15  time          25772 non-null  object
#  16  timeformat    25772 non-null  object
#  17  fighter_id_1  25772 non-null  object
#  18  ss_de         25772 non-null  float64
#  19  sss_di        25772 non-null  int64
#  20  ssa_di        25772 non-null  int64
#  21  round_length  25772 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(7), object(11)
# memory usage: 4.5+ MB

# %% [markdown]
# ### Calculate assa-m
#
# before calculating, we need to convert the round length column into a timedelta object.

# %%
new_data.round_length = '00:0' + new_data.round_length

# %%
new_data.round_length = pd.to_timedelta(new_data.round_length)

# %%
new_data.round_length.describe()
# Out:
# count                     25772
# mean     0 days 00:04:28.456774
# std      0 days 00:01:10.459661
# min             0 days 00:00:05
# 25%             0 days 00:05:00
# 50%             0 days 00:05:00
# 75%             0 days 00:05:00
# max             0 days 00:05:00
# Name: round_length, dtype: object

# %%
new_data['minutes'] = new_data.round_length.map(lambda x: x.total_seconds()/60)

# %%
new_data['ssa_p1m'] = new_data['ssa'] / new_data.minutes
new_data['sss_p1m'] = new_data['sss'] / new_data.minutes
new_data
# Out:
#        index                                          bout_link  \
# 0          0  http://www.ufcstats.com/fight-details/11f715fa...
# 13107      0  http://www.ufcstats.com/fight-details/11f715fa...
# 1          1  http://www.ufcstats.com/fight-details/11f715fa...
# 13108      1  http://www.ufcstats.com/fight-details/11f715fa...
# 2          2  http://www.ufcstats.com/fight-details/11f715fa...
# ...      ...                                                ...
# 25990  12883  http://www.ufcstats.com/fight-details/c6f85419...
# 12884  12884  http://www.ufcstats.com/fight-details/1db8bed8...
# 25991  12884  http://www.ufcstats.com/fight-details/1db8bed8...
# 12885  12885  http://www.ufcstats.com/fight-details/1db8bed8...
# 25992  12885  http://www.ufcstats.com/fight-details/1db8bed8...
#
#                                             fighter_link  ssa  sss       date  \
# 0      http://www.ufcstats.com/fighter-details/e1147d...   30   11 2020-07-25
# 13107  http://www.ufcstats.com/fighter-details/9ce6d5...   24   12 2020-07-25
# 1      http://www.ufcstats.com/fighter-details/e1147d...   30   15 2020-07-25
# 13108  http://www.ufcstats.com/fighter-details/9ce6d5...   12    3 2020-07-25
# 2      http://www.ufcstats.com/fighter-details/e1147d...   32   13 2020-07-25
# ...                                                  ...  ...  ...        ...
# 25990  http://www.ufcstats.com/fighter-details/a54a35...   20   10 1999-07-16
# 12884  http://www.ufcstats.com/fighter-details/c2a762...    0    0 1999-07-16
# 25991  http://www.ufcstats.com/fighter-details/911fb2...   13    9 1999-07-16
# 12885  http://www.ufcstats.com/fighter-details/c2a762...    0    0 1999-07-16
# 25992  http://www.ufcstats.com/fighter-details/911fb2...   19   16 1999-07-16
#
#       round     ss_ac        fighter_id           bout_id  ...  time  \
# 0         1  0.366667  e1147d3d2dabe1ce  11f715fa5e825e51  ...  5:00
# 13107     1  0.500000  9ce6d5a03af801b7  11f715fa5e825e51  ...  5:00
# 1         2  0.500000  e1147d3d2dabe1ce  11f715fa5e825e51  ...  5:00
# 13108     2  0.250000  9ce6d5a03af801b7  11f715fa5e825e51  ...  5:00
# 2         3  0.406250  e1147d3d2dabe1ce  11f715fa5e825e51  ...  5:00
# ...     ...       ...               ...               ...  ...   ...
# 25990     1  0.500000  a54a35a670d8e852  c6f8541973f69080  ...  2:51
# 12884     1  0.000000  c2a7623f398d9bd7  1db8bed8b4d30fb3  ...  5:00
# 25991     1  0.692308  911fb265462f0d94  1db8bed8b4d30fb3  ...  5:00
# 12885     2  0.000000  c2a7623f398d9bd7  1db8bed8b4d30fb3  ...  5:00
# 25992     2  0.842105  911fb265462f0d94  1db8bed8b4d30fb3  ...  5:00
#
#               timeformat      fighter_id_1     ss_de  sss_di ssa_di  \
# 0      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.500000      -1      6
# 13107  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.633333       1     -6
# 1      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.750000      12     18
# 13108  5 Rnd (5-5-5-5-5)  e1147d3d2dabe1ce  0.500000     -12    -18
# 2      5 Rnd (5-5-5-5-5)  9ce6d5a03af801b7  0.714286       7     11
# ...                  ...               ...       ...     ...    ...
# 25990        2 Rnd (5-5)  efaf544314bb5c2e  0.541667     -12    -28
# 12884        2 Rnd (5-5)  911fb265462f0d94  0.307692      -9    -13
# 25991        2 Rnd (5-5)  c2a7623f398d9bd7  1.000000       9     13
# 12885        2 Rnd (5-5)  911fb265462f0d94  0.157895     -16    -19
# 25992        2 Rnd (5-5)  c2a7623f398d9bd7  1.000000      16     19
#
#       round_length minutes   ssa_p1m   sss_p1m
# 0         00:05:00    5.00  6.000000  2.200000
# 13107     00:05:00    5.00  4.800000  2.400000
# 1         00:05:00    5.00  6.000000  3.000000
# 13108     00:05:00    5.00  2.400000  0.600000
# 2         00:05:00    5.00  6.400000  2.600000
# ...            ...     ...       ...       ...
# 25990     00:02:51    2.85  7.017544  3.508772
# 12884     00:05:00    5.00  0.000000  0.000000
# 25991     00:05:00    5.00  2.600000  1.800000
# 12885     00:05:00    5.00  0.000000  0.000000
# 25992     00:05:00    5.00  3.800000  3.200000
#
# [25772 rows x 25 columns]

# %%
new_data.ssa_p1m.describe()
# Out:
# count    25772.000000
# mean         7.758239
# std          5.656875
# min          0.000000
# 25%          3.800000
# 50%          6.600000
# 75%         10.400000
# max         95.000000
# Name: ssa_p1m, dtype: float64

# %%
data=new_data

# %% [markdown]
# ## Clean up
# Clean the new dataframe so that it has all of the info in the correct places and then I'm going to merge it with the original strikes table.

# %%
data.columns
# Out:
# Index(['index', 'bout_link', 'fighter_link', 'ssa', 'sss', 'date', 'round',
#        'ss_ac', 'fighter_id', 'bout_id', 'round_id', 'inst_id', 'ssa_1',
#        'sss_1', 'ss_ac_1', 'time', 'timeformat', 'fighter_id_1', 'ss_de',
#        'sss_di', 'ssa_di', 'round_length', 'minutes', 'ssa_p1m', 'sss_p1m'],
#       dtype='object')

# %%
to_drop = ['index', 'round_length', 'timeformat', 'time']
data.drop(to_drop, axis=1, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25772 entries, 0 to 25992
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   bout_link     25772 non-null  object
#  1   fighter_link  25772 non-null  object
#  2   ssa           25772 non-null  int64
#  3   sss           25772 non-null  int64
#  4   date          25772 non-null  datetime64[ns]
#  5   round         25772 non-null  object
#  6   ss_ac         25772 non-null  float64
#  7   fighter_id    25772 non-null  object
#  8   bout_id       25772 non-null  object
#  9   round_id      25772 non-null  object
#  10  inst_id       25772 non-null  object
#  11  ssa_1         25772 non-null  int64
#  12  sss_1         25772 non-null  int64
#  13  ss_ac_1       25772 non-null  float64
#  14  fighter_id_1  25772 non-null  object
#  15  ss_de         25772 non-null  float64
#  16  sss_di        25772 non-null  int64
#  17  ssa_di        25772 non-null  int64
#  18  minutes       25772 non-null  float64
#  19  ssa_p1m       25772 non-null  float64
#  20  sss_p1m       25772 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(6), object(8)
# memory usage: 4.3+ MB

# %%
data.columns
# Out:
# Index(['bout_link', 'fighter_link', 'ssa', 'sss', 'date', 'round', 'ss_ac',
#        'fighter_id', 'bout_id', 'round_id', 'inst_id', 'ssa_1', 'sss_1',
#        'ss_ac_1', 'fighter_id_1', 'ss_de', 'sss_di', 'ssa_di', 'minutes',
#        'ssa_p1m', 'sss_p1m'],
#       dtype='object')

# %%
data = data.loc[:,['date', 'bout_link', 'fighter_link', 'round', 'minutes',
            'ssa', 'sss', 'ss_ac', 'ss_de', 'sss_di', 'ssa_di', 'ssa_p1m', 'sss_p1m',
            'fighter_id_1', 'ssa_1', 'sss_1', 'ss_ac_1']]

# %%
data.to_csv('../../data/ufcstats_data/fighter_round_performance.csv', index=False)
