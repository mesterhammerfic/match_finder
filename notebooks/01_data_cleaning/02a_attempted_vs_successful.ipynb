# %% [markdown]
# # Purpose
# Separate the columns for each strike statistic into attempted and landed columns.
# For example, the sig_str column will be split into:
#  - sig_str_a: how many significant strikes were attempted
#  - sig_str_s: how many significant strikes were successful
#
# The outcome of this notebook will be a new sql table witht eh new columns replacing the old ones.
# The new table will be called strikes_clean

# %%
import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
from sqlalchemy import create_engine
from src import local

# %%
# Credentials
USER = local.user 
PASS = local.password
HOST = local.host
PORT = local.port

#create engine
engine = create_engine(f'postgresql://{USER}:{PASS}@{HOST}:{PORT}/match_finder')

# %% [markdown]
# # Get strikes table from postgres database

# %%
query = """
SELECT *
FROM strikes
"""

data = pd.read_sql(query, engine)

# %%
data
# Out:
#                 fighter    sig_str sig_str_prcnt      head     body      leg  \
# 0      Robert Whittaker   11 of 30           36%   4 of 22   1 of 2   6 of 6
# 1      Robert Whittaker   15 of 30           50%   7 of 22   1 of 1   7 of 7
# 2      Robert Whittaker   13 of 32           40%   8 of 26   0 of 1   5 of 5
# 3      Robert Whittaker   13 of 34           38%   7 of 26   1 of 2   5 of 6
# 4      Robert Whittaker   17 of 31           54%   6 of 20   4 of 4   7 of 7
# ...                 ...        ...           ...       ...      ...      ...
# 26239     Art Jimmerson     0 of 0            0%    0 of 0   0 of 0   0 of 0
# 26240      Kevin Rosier   15 of 27           55%  12 of 23   3 of 4   0 of 0
# 26241      Zane Frazier   12 of 28           42%   7 of 19   3 of 6   2 of 3
# 26242    Gerard Gordeau     3 of 5           60%    3 of 5   0 of 0   0 of 0
# 26243        Teila Tuli     0 of 1            0%    0 of 1   0 of 0   0 of 0
#
#        distance     clinch   ground  round  \
# 0      10 of 29     1 of 1   0 of 0      1
# 1      10 of 23     0 of 0   5 of 7      2
# 2      11 of 30     2 of 2   0 of 0      3
# 3      12 of 31     1 of 3   0 of 0      4
# 4      14 of 26     3 of 5   0 of 0      5
# ...         ...        ...      ...    ...
# 26239    0 of 0     0 of 0   0 of 0      1
# 26240   4 of 10     4 of 9   7 of 8      1
# 26241    0 of 7   10 of 19   2 of 2      1
# 26242    1 of 3     0 of 0   2 of 2      1
# 26243    0 of 1     0 of 0   0 of 0      1
#
#                                                bout_link outcome  \
# 0      http://www.ufcstats.com/fight-details/11f715fa...       W
# 1      http://www.ufcstats.com/fight-details/11f715fa...       W
# 2      http://www.ufcstats.com/fight-details/11f715fa...       W
# 3      http://www.ufcstats.com/fight-details/11f715fa...       W
# 4      http://www.ufcstats.com/fight-details/11f715fa...       W
# ...                                                  ...     ...
# 26239  http://www.ufcstats.com/fight-details/cecdc0da...       L
# 26240  http://www.ufcstats.com/fight-details/2d2bbc86...       W
# 26241  http://www.ufcstats.com/fight-details/2d2bbc86...       L
# 26242  http://www.ufcstats.com/fight-details/567a09fd...       W
# 26243  http://www.ufcstats.com/fight-details/567a09fd...       L
#
#                                             fighter_link
# 0      http://www.ufcstats.com/fighter-details/e1147d...
# 1      http://www.ufcstats.com/fighter-details/e1147d...
# 2      http://www.ufcstats.com/fighter-details/e1147d...
# 3      http://www.ufcstats.com/fighter-details/e1147d...
# 4      http://www.ufcstats.com/fighter-details/e1147d...
# ...                                                  ...
# 26239  http://www.ufcstats.com/fighter-details/a5c53b...
# 26240  http://www.ufcstats.com/fighter-details/598a58...
# 26241  http://www.ufcstats.com/fighter-details/d3711d...
# 26242  http://www.ufcstats.com/fighter-details/279093...
# 26243  http://www.ufcstats.com/fighter-details/96eff1...
#
# [26244 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26244 entries, 0 to 26243
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fighter        26244 non-null  object
#  1   sig_str        26244 non-null  object
#  2   sig_str_prcnt  26244 non-null  object
#  3   head           26244 non-null  object
#  4   body           26244 non-null  object
#  5   leg            26244 non-null  object
#  6   distance       26244 non-null  object
#  7   clinch         26244 non-null  object
#  8   ground         26244 non-null  object
#  9   round          26244 non-null  int64
#  10  bout_link      26244 non-null  object
#  11  outcome        26244 non-null  object
#  12  fighter_link   26244 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 2.6+ MB

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ## Create successful significant strikes column
# The following steps will be turned into a function that can be applied to all columns.
# #### First, remove whitespace from the column

# %%
data['sig_str'] = data['sig_str'].map(lambda x: x.strip())

# %% [markdown]
# #### Create functions that return the first number in a string as successes, and the second number as attempts

# %%
def get_successful(string):
    """
    input: a string that follows the format: [number landed] of [number thrown] 
                                            ie 11 of 30 means they landed 11 strikes out of 30
    output: an integer of the number landed
                                            ie 11 from the example above
    """
    return int(string.split(' ')[0])

# %%
def get_attempts(string):
    """
    input: a string that follows the format: [number landed] of [number thrown] 
                                            ie 11 of 30 means they landed 11 strikes out of 30
    output: an integer of the number attempted
                                            ie 30 from the example above
    """
    return int(string.split(' ')[-1])

# %%
data['sig_str'+'_s'] = data['sig_str'].map(get_successful)
data['sig_str'+'_a'] = data['sig_str'].map(get_attempts)

# %%
data
# Out:
#                 fighter   sig_str sig_str_prcnt      head     body      leg  \
# 0      Robert Whittaker  11 of 30           36%   4 of 22   1 of 2   6 of 6
# 1      Robert Whittaker  15 of 30           50%   7 of 22   1 of 1   7 of 7
# 2      Robert Whittaker  13 of 32           40%   8 of 26   0 of 1   5 of 5
# 3      Robert Whittaker  13 of 34           38%   7 of 26   1 of 2   5 of 6
# 4      Robert Whittaker  17 of 31           54%   6 of 20   4 of 4   7 of 7
# ...                 ...       ...           ...       ...      ...      ...
# 26239     Art Jimmerson    0 of 0            0%    0 of 0   0 of 0   0 of 0
# 26240      Kevin Rosier  15 of 27           55%  12 of 23   3 of 4   0 of 0
# 26241      Zane Frazier  12 of 28           42%   7 of 19   3 of 6   2 of 3
# 26242    Gerard Gordeau    3 of 5           60%    3 of 5   0 of 0   0 of 0
# 26243        Teila Tuli    0 of 1            0%    0 of 1   0 of 0   0 of 0
#
#        distance     clinch   ground  round  \
# 0      10 of 29     1 of 1   0 of 0      1
# 1      10 of 23     0 of 0   5 of 7      2
# 2      11 of 30     2 of 2   0 of 0      3
# 3      12 of 31     1 of 3   0 of 0      4
# 4      14 of 26     3 of 5   0 of 0      5
# ...         ...        ...      ...    ...
# 26239    0 of 0     0 of 0   0 of 0      1
# 26240   4 of 10     4 of 9   7 of 8      1
# 26241    0 of 7   10 of 19   2 of 2      1
# 26242    1 of 3     0 of 0   2 of 2      1
# 26243    0 of 1     0 of 0   0 of 0      1
#
#                                                bout_link outcome  \
# 0      http://www.ufcstats.com/fight-details/11f715fa...       W
# 1      http://www.ufcstats.com/fight-details/11f715fa...       W
# 2      http://www.ufcstats.com/fight-details/11f715fa...       W
# 3      http://www.ufcstats.com/fight-details/11f715fa...       W
# 4      http://www.ufcstats.com/fight-details/11f715fa...       W
# ...                                                  ...     ...
# 26239  http://www.ufcstats.com/fight-details/cecdc0da...       L
# 26240  http://www.ufcstats.com/fight-details/2d2bbc86...       W
# 26241  http://www.ufcstats.com/fight-details/2d2bbc86...       L
# 26242  http://www.ufcstats.com/fight-details/567a09fd...       W
# 26243  http://www.ufcstats.com/fight-details/567a09fd...       L
#
#                                             fighter_link  sig_str_s  sig_str_a
# 0      http://www.ufcstats.com/fighter-details/e1147d...         11         30
# 1      http://www.ufcstats.com/fighter-details/e1147d...         15         30
# 2      http://www.ufcstats.com/fighter-details/e1147d...         13         32
# 3      http://www.ufcstats.com/fighter-details/e1147d...         13         34
# 4      http://www.ufcstats.com/fighter-details/e1147d...         17         31
# ...                                                  ...        ...        ...
# 26239  http://www.ufcstats.com/fighter-details/a5c53b...          0          0
# 26240  http://www.ufcstats.com/fighter-details/598a58...         15         27
# 26241  http://www.ufcstats.com/fighter-details/d3711d...         12         28
# 26242  http://www.ufcstats.com/fighter-details/279093...          3          5
# 26243  http://www.ufcstats.com/fighter-details/96eff1...          0          1
#
# [26244 rows x 15 columns]

# %% [markdown]
# ## Create clean dataframe
# Now that I successfully did this with the first column, I will select which columns I want to do this to next and put them into a list. With this list I will iterate over the columns adding the new ones.

# %%
list(data.columns)
# Out:
# ['fighter',
#  'sig_str',
#  'sig_str_prcnt',
#  'head',
#  'body',
#  'leg',
#  'distance',
#  'clinch',
#  'ground',
#  'round',
#  'bout_link',
#  'outcome',
#  'fighter_link',
#  'sig_str_s',
#  'sig_str_a']

# %%
to_be_formatted = ['sig_str',
                 'head',
                 'body',
                 'leg',
                 'distance',
                 'clinch',
                 'ground']

# %%
for column in to_be_formatted:
    data[column] = data[column].map(lambda x: x.strip())
    data[column+'_successful'] = data[column].map(get_successful)
    data[column+'_attempts'] = data[column].map(get_attempts)

# %%
data
# Out:
#                 fighter   sig_str sig_str_prcnt      head    body     leg  \
# 0      Robert Whittaker  11 of 30           36%   4 of 22  1 of 2  6 of 6
# 1      Robert Whittaker  15 of 30           50%   7 of 22  1 of 1  7 of 7
# 2      Robert Whittaker  13 of 32           40%   8 of 26  0 of 1  5 of 5
# 3      Robert Whittaker  13 of 34           38%   7 of 26  1 of 2  5 of 6
# 4      Robert Whittaker  17 of 31           54%   6 of 20  4 of 4  7 of 7
# ...                 ...       ...           ...       ...     ...     ...
# 26239     Art Jimmerson    0 of 0            0%    0 of 0  0 of 0  0 of 0
# 26240      Kevin Rosier  15 of 27           55%  12 of 23  3 of 4  0 of 0
# 26241      Zane Frazier  12 of 28           42%   7 of 19  3 of 6  2 of 3
# 26242    Gerard Gordeau    3 of 5           60%    3 of 5  0 of 0  0 of 0
# 26243        Teila Tuli    0 of 1            0%    0 of 1  0 of 0  0 of 0
#
#        distance    clinch  ground  round  ... body_successful body_attempts  \
# 0      10 of 29    1 of 1  0 of 0      1  ...               1             2
# 1      10 of 23    0 of 0  5 of 7      2  ...               1             1
# 2      11 of 30    2 of 2  0 of 0      3  ...               0             1
# 3      12 of 31    1 of 3  0 of 0      4  ...               1             2
# 4      14 of 26    3 of 5  0 of 0      5  ...               4             4
# ...         ...       ...     ...    ...  ...             ...           ...
# 26239    0 of 0    0 of 0  0 of 0      1  ...               0             0
# 26240   4 of 10    4 of 9  7 of 8      1  ...               3             4
# 26241    0 of 7  10 of 19  2 of 2      1  ...               3             6
# 26242    1 of 3    0 of 0  2 of 2      1  ...               0             0
# 26243    0 of 1    0 of 0  0 of 0      1  ...               0             0
#
#       leg_successful  leg_attempts  distance_successful  distance_attempts  \
# 0                  6             6                   10                 29
# 1                  7             7                   10                 23
# 2                  5             5                   11                 30
# 3                  5             6                   12                 31
# 4                  7             7                   14                 26
# ...              ...           ...                  ...                ...
# 26239              0             0                    0                  0
# 26240              0             0                    4                 10
# 26241              2             3                    0                  7
# 26242              0             0                    1                  3
# 26243              0             0                    0                  1
#
#        clinch_successful  clinch_attempts  ground_successful  ground_attempts
# 0                      1                1                  0                0
# 1                      0                0                  5                7
# 2                      2                2                  0                0
# 3                      1                3                  0                0
# 4                      3                5                  0                0
# ...                  ...              ...                ...              ...
# 26239                  0                0                  0                0
# 26240                  4                9                  7                8
# 26241                 10               19                  2                2
# 26242                  0                0                  2                2
# 26243                  0                0                  0                0
#
# [26244 rows x 29 columns]

# %% [markdown]
# ## Remove old rows

# %%
to_be_dropped = ['sig_str',
             'head',
             'body',
             'leg',
             'distance',
             'clinch',
             'ground',
             'sig_str_prcnt']

data.drop(to_be_dropped, axis=1, inplace=True)

# %%
data
# Out:
#                 fighter  round  \
# 0      Robert Whittaker      1
# 1      Robert Whittaker      2
# 2      Robert Whittaker      3
# 3      Robert Whittaker      4
# 4      Robert Whittaker      5
# ...                 ...    ...
# 26239     Art Jimmerson      1
# 26240      Kevin Rosier      1
# 26241      Zane Frazier      1
# 26242    Gerard Gordeau      1
# 26243        Teila Tuli      1
#
#                                                bout_link outcome  \
# 0      http://www.ufcstats.com/fight-details/11f715fa...       W
# 1      http://www.ufcstats.com/fight-details/11f715fa...       W
# 2      http://www.ufcstats.com/fight-details/11f715fa...       W
# 3      http://www.ufcstats.com/fight-details/11f715fa...       W
# 4      http://www.ufcstats.com/fight-details/11f715fa...       W
# ...                                                  ...     ...
# 26239  http://www.ufcstats.com/fight-details/cecdc0da...       L
# 26240  http://www.ufcstats.com/fight-details/2d2bbc86...       W
# 26241  http://www.ufcstats.com/fight-details/2d2bbc86...       L
# 26242  http://www.ufcstats.com/fight-details/567a09fd...       W
# 26243  http://www.ufcstats.com/fight-details/567a09fd...       L
#
#                                             fighter_link  sig_str_s  \
# 0      http://www.ufcstats.com/fighter-details/e1147d...         11
# 1      http://www.ufcstats.com/fighter-details/e1147d...         15
# 2      http://www.ufcstats.com/fighter-details/e1147d...         13
# 3      http://www.ufcstats.com/fighter-details/e1147d...         13
# 4      http://www.ufcstats.com/fighter-details/e1147d...         17
# ...                                                  ...        ...
# 26239  http://www.ufcstats.com/fighter-details/a5c53b...          0
# 26240  http://www.ufcstats.com/fighter-details/598a58...         15
# 26241  http://www.ufcstats.com/fighter-details/d3711d...         12
# 26242  http://www.ufcstats.com/fighter-details/279093...          3
# 26243  http://www.ufcstats.com/fighter-details/96eff1...          0
#
#        sig_str_a  sig_str_successful  sig_str_attempts  head_successful  ...  \
# 0             30                  11                30                4  ...
# 1             30                  15                30                7  ...
# 2             32                  13                32                8  ...
# 3             34                  13                34                7  ...
# 4             31                  17                31                6  ...
# ...          ...                 ...               ...              ...  ...
# 26239          0                   0                 0                0  ...
# 26240         27                  15                27               12  ...
# 26241         28                  12                28                7  ...
# 26242          5                   3                 5                3  ...
# 26243          1                   0                 1                0  ...
#
#        body_successful  body_attempts  leg_successful  leg_attempts  \
# 0                    1              2               6             6
# 1                    1              1               7             7
# 2                    0              1               5             5
# 3                    1              2               5             6
# 4                    4              4               7             7
# ...                ...            ...             ...           ...
# 26239                0              0               0             0
# 26240                3              4               0             0
# 26241                3              6               2             3
# 26242                0              0               0             0
# 26243                0              0               0             0
#
#        distance_successful  distance_attempts  clinch_successful  \
# 0                       10                 29                  1
# 1                       10                 23                  0
# 2                       11                 30                  2
# 3                       12                 31                  1
# 4                       14                 26                  3
# ...                    ...                ...                ...
# 26239                    0                  0                  0
# 26240                    4                 10                  4
# 26241                    0                  7                 10
# 26242                    1                  3                  0
# 26243                    0                  1                  0
#
#        clinch_attempts  ground_successful  ground_attempts
# 0                    1                  0                0
# 1                    0                  5                7
# 2                    2                  0                0
# 3                    3                  0                0
# 4                    5                  0                0
# ...                ...                ...              ...
# 26239                0                  0                0
# 26240                9                  7                8
# 26241               19                  2                2
# 26242                0                  2                2
# 26243                0                  0                0
#
# [26244 rows x 21 columns]

# %% [markdown]
# ## Send to sql

# %%
data.to_sql('strikes_cleaned', engine, index=False)

# %% [markdown]
# ## Clean general table

# %%
query = """
SELECT *
FROM general
"""

general = pd.read_sql(query, engine)

# %%
general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26244 entries, 0 to 26243
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fighter        26244 non-null  object
#  1   kd             26244 non-null  int64
#  2   sig_str        26244 non-null  object
#  3   sig_str_prcnt  26244 non-null  object
#  4   total_str      26244 non-null  object
#  5   td_count       26244 non-null  object
#  6   td_prcnt       26244 non-null  object
#  7   sub_att        26244 non-null  int64
#  8   pass           26244 non-null  int64
#  9   rev            26244 non-null  int64
#  10  round          26244 non-null  int64
#  11  bout_id        26244 non-null  object
#  12  outcome        26244 non-null  object
#  13  fighter_link   26244 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 2.8+ MB

# %%
general.head()
# Out:
#             fighter  kd   sig_str sig_str_prcnt total_str td_count td_prcnt  \
# 0  Robert Whittaker   0  11 of 30           36%  13 of 32   0 of 2       0%
# 1  Robert Whittaker   1  15 of 30           50%  42 of 57   0 of 0       0%
# 2  Robert Whittaker   0  13 of 32           40%  13 of 32   0 of 2       0%
# 3  Robert Whittaker   0  13 of 34           38%  14 of 35   0 of 2       0%
# 4  Robert Whittaker   0  17 of 31           54%  18 of 32   2 of 7      28%
#
#    sub_att  pass  rev  round  \
# 0        0     0    0      1
# 1        0     1    0      2
# 2        0     0    0      3
# 3        0     0    0      4
# 4        0     0    0      5
#
#                                              bout_id outcome  \
# 0  http://www.ufcstats.com/fight-details/11f715fa...       W
# 1  http://www.ufcstats.com/fight-details/11f715fa...       W
# 2  http://www.ufcstats.com/fight-details/11f715fa...       W
# 3  http://www.ufcstats.com/fight-details/11f715fa...       W
# 4  http://www.ufcstats.com/fight-details/11f715fa...       W
#
#                                         fighter_link
# 0  http://www.ufcstats.com/fighter-details/e1147d...
# 1  http://www.ufcstats.com/fighter-details/e1147d...
# 2  http://www.ufcstats.com/fighter-details/e1147d...
# 3  http://www.ufcstats.com/fighter-details/e1147d...
# 4  http://www.ufcstats.com/fighter-details/e1147d...

# %%
list(general.columns)
# Out:
# ['fighter',
#  'kd',
#  'sig_str',
#  'sig_str_prcnt',
#  'total_str',
#  'td_count',
#  'td_prcnt',
#  'sub_att',
#  'pass',
#  'rev',
#  'round',
#  'bout_id',
#  'outcome',
#  'fighter_link']

# %%
to_be_formatted = ['total_str',
                     'td_count']

# %%
for column in to_be_formatted:
    general[column] = general[column].map(lambda x: x.strip())
    general[column+'_successful'] = general[column].map(get_successful)
    general[column+'_attempts'] = general[column].map(get_attempts)

# %%
general
# Out:
#                 fighter  kd    sig_str sig_str_prcnt total_str td_count  \
# 0      Robert Whittaker   0   11 of 30           36%  13 of 32   0 of 2
# 1      Robert Whittaker   1   15 of 30           50%  42 of 57   0 of 0
# 2      Robert Whittaker   0   13 of 32           40%  13 of 32   0 of 2
# 3      Robert Whittaker   0   13 of 34           38%  14 of 35   0 of 2
# 4      Robert Whittaker   0   17 of 31           54%  18 of 32   2 of 7
# ...                 ...  ..        ...           ...       ...      ...
# 26239     Art Jimmerson   0     0 of 0            0%    0 of 0   0 of 0
# 26240      Kevin Rosier   2   15 of 27           55%  38 of 53   0 of 0
# 26241      Zane Frazier   0   12 of 28           42%  13 of 29   0 of 0
# 26242    Gerard Gordeau   0     3 of 5           60%    3 of 5   0 of 0
# 26243        Teila Tuli   0     0 of 1            0%    0 of 1   0 of 1
#
#       td_prcnt  sub_att  pass  rev  round  \
# 0           0%        0     0    0      1
# 1           0%        0     1    0      2
# 2           0%        0     0    0      3
# 3           0%        0     0    0      4
# 4          28%        0     0    0      5
# ...        ...      ...   ...  ...    ...
# 26239       0%        0     0    0      1
# 26240       0%        0     0    0      1
# 26241       0%        0     0    0      1
# 26242       0%        0     0    0      1
# 26243       0%        0     0    0      1
#
#                                                  bout_id outcome  \
# 0      http://www.ufcstats.com/fight-details/11f715fa...       W
# 1      http://www.ufcstats.com/fight-details/11f715fa...       W
# 2      http://www.ufcstats.com/fight-details/11f715fa...       W
# 3      http://www.ufcstats.com/fight-details/11f715fa...       W
# 4      http://www.ufcstats.com/fight-details/11f715fa...       W
# ...                                                  ...     ...
# 26239  http://www.ufcstats.com/fight-details/cecdc0da...       L
# 26240  http://www.ufcstats.com/fight-details/2d2bbc86...       W
# 26241  http://www.ufcstats.com/fight-details/2d2bbc86...       L
# 26242  http://www.ufcstats.com/fight-details/567a09fd...       W
# 26243  http://www.ufcstats.com/fight-details/567a09fd...       L
#
#                                             fighter_link  \
# 0      http://www.ufcstats.com/fighter-details/e1147d...
# 1      http://www.ufcstats.com/fighter-details/e1147d...
# 2      http://www.ufcstats.com/fighter-details/e1147d...
# 3      http://www.ufcstats.com/fighter-details/e1147d...
# 4      http://www.ufcstats.com/fighter-details/e1147d...
# ...                                                  ...
# 26239  http://www.ufcstats.com/fighter-details/a5c53b...
# 26240  http://www.ufcstats.com/fighter-details/598a58...
# 26241  http://www.ufcstats.com/fighter-details/d3711d...
# 26242  http://www.ufcstats.com/fighter-details/279093...
# 26243  http://www.ufcstats.com/fighter-details/96eff1...
#
#        total_str_successful  total_str_attempts  td_count_successful  \
# 0                        13                  32                    0
# 1                        42                  57                    0
# 2                        13                  32                    0
# 3                        14                  35                    0
# 4                        18                  32                    2
# ...                     ...                 ...                  ...
# 26239                     0                   0                    0
# 26240                    38                  53                    0
# 26241                    13                  29                    0
# 26242                     3                   5                    0
# 26243                     0                   1                    0
#
#        td_count_attempts
# 0                      2
# 1                      0
# 2                      2
# 3                      2
# 4                      7
# ...                  ...
# 26239                  0
# 26240                  0
# 26241                  0
# 26242                  0
# 26243                  1
#
# [26244 rows x 18 columns]

# %%
to_be_dropped = ['sig_str',
                 'sig_str_prcnt',
                 'total_str',
                 'td_count',
                 'td_prcnt',]

general.drop(to_be_dropped, axis=1, inplace=True)

# %%
general
# Out:
#                 fighter  kd  sub_att  pass  rev  round  \
# 0      Robert Whittaker   0        0     0    0      1
# 1      Robert Whittaker   1        0     1    0      2
# 2      Robert Whittaker   0        0     0    0      3
# 3      Robert Whittaker   0        0     0    0      4
# 4      Robert Whittaker   0        0     0    0      5
# ...                 ...  ..      ...   ...  ...    ...
# 26239     Art Jimmerson   0        0     0    0      1
# 26240      Kevin Rosier   2        0     0    0      1
# 26241      Zane Frazier   0        0     0    0      1
# 26242    Gerard Gordeau   0        0     0    0      1
# 26243        Teila Tuli   0        0     0    0      1
#
#                                                  bout_id outcome  \
# 0      http://www.ufcstats.com/fight-details/11f715fa...       W
# 1      http://www.ufcstats.com/fight-details/11f715fa...       W
# 2      http://www.ufcstats.com/fight-details/11f715fa...       W
# 3      http://www.ufcstats.com/fight-details/11f715fa...       W
# 4      http://www.ufcstats.com/fight-details/11f715fa...       W
# ...                                                  ...     ...
# 26239  http://www.ufcstats.com/fight-details/cecdc0da...       L
# 26240  http://www.ufcstats.com/fight-details/2d2bbc86...       W
# 26241  http://www.ufcstats.com/fight-details/2d2bbc86...       L
# 26242  http://www.ufcstats.com/fight-details/567a09fd...       W
# 26243  http://www.ufcstats.com/fight-details/567a09fd...       L
#
#                                             fighter_link  \
# 0      http://www.ufcstats.com/fighter-details/e1147d...
# 1      http://www.ufcstats.com/fighter-details/e1147d...
# 2      http://www.ufcstats.com/fighter-details/e1147d...
# 3      http://www.ufcstats.com/fighter-details/e1147d...
# 4      http://www.ufcstats.com/fighter-details/e1147d...
# ...                                                  ...
# 26239  http://www.ufcstats.com/fighter-details/a5c53b...
# 26240  http://www.ufcstats.com/fighter-details/598a58...
# 26241  http://www.ufcstats.com/fighter-details/d3711d...
# 26242  http://www.ufcstats.com/fighter-details/279093...
# 26243  http://www.ufcstats.com/fighter-details/96eff1...
#
#        total_str_successful  total_str_attempts  td_count_successful  \
# 0                        13                  32                    0
# 1                        42                  57                    0
# 2                        13                  32                    0
# 3                        14                  35                    0
# 4                        18                  32                    2
# ...                     ...                 ...                  ...
# 26239                     0                   0                    0
# 26240                    38                  53                    0
# 26241                    13                  29                    0
# 26242                     3                   5                    0
# 26243                     0                   1                    0
#
#        td_count_attempts
# 0                      2
# 1                      0
# 2                      2
# 3                      2
# 4                      7
# ...                  ...
# 26239                  0
# 26240                  0
# 26241                  0
# 26242                  0
# 26243                  1
#
# [26244 rows x 13 columns]

# %%
general.to_sql('general_cleaned', engine, index=False)
